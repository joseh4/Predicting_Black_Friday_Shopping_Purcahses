# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df.Product_Category_1.unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19])

# %%
df.Product_Category_2.unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df.Product_Category_3.unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df.loc[df['User_ID']==1000001]
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 39180   1000001  P00085942      F  0-17          10             A
# 78144   1000001  P00102642      F  0-17          10             A
# 78145   1000001  P00110842      F  0-17          10             A
# 78146   1000001  P00004842      F  0-17          10             A
# 116848  1000001  P00117942      F  0-17          10             A
# 116849  1000001  P00258742      F  0-17          10             A
# 116850  1000001  P00142242      F  0-17          10             A
# 116851  1000001  P00000142      F  0-17          10             A
# 155570  1000001  P00297042      F  0-17          10             A
# 155571  1000001  P00059442      F  0-17          10             A
# 155572  1000001   P0096542      F  0-17          10             A
# 194558  1000001  P00184942      F  0-17          10             A
# 194559  1000001  P00051842      F  0-17          10             A
# 233726  1000001  P00214842      F  0-17          10             A
# 233727  1000001  P00165942      F  0-17          10             A
# 233728  1000001  P00111842      F  0-17          10             A
# 272808  1000001  P00178242      F  0-17          10             A
# 311709  1000001  P00178342      F  0-17          10             A
# 311710  1000001  P00183942      F  0-17          10             A
# 311711  1000001  P00051442      F  0-17          10             A
# 311712  1000001  P00248442      F  0-17          10             A
# 311713  1000001  P00210342      F  0-17          10             A
# 350797  1000001  P00289942      F  0-17          10             A
# 390150  1000001   P0097142      F  0-17          10             A
# 390151  1000001  P00255842      F  0-17          10             A
# 428893  1000001  P00025442      F  0-17          10             A
# 428894  1000001  P00074142      F  0-17          10             A
# 467663  1000001  P00058142      F  0-17          10             A
# 467664  1000001  P00220642      F  0-17          10             A
# 506601  1000001  P00064042      F  0-17          10             A
# 545915  1000001  P00375436      F  0-17          10             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 39180                           2               0                   2
# 78144                           2               0                   4
# 78145                           2               0                   1
# 78146                           2               0                   3
# 116848                          2               0                   5
# 116849                          2               0                   5
# 116850                          2               0                   8
# 116851                          2               0                   3
# 155570                          2               0                   8
# 155571                          2               0                   6
# 155572                          2               0                   3
# 194558                          2               0                   1
# 194559                          2               0                   4
# 233726                          2               0                  14
# 233727                          2               0                   8
# 233728                          2               0                   8
# 272808                          2               0                   8
# 311709                          2               0                   8
# 311710                          2               0                   3
# 311711                          2               0                   8
# 311712                          2               0                   3
# 311713                          2               0                   3
# 350797                          2               0                   3
# 390150                          2               0                  12
# 390151                          2               0                  16
# 428893                          2               0                   1
# 428894                          2               0                   3
# 467663                          2               0                   3
# 467664                          2               0                   8
# 506601                          2               0                   3
# 545915                          2               0                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 39180                  4.0                 8.0     12842
# 78144                  8.0                 9.0      2763
# 78145                  2.0                 5.0     11769
# 78146                  4.0                12.0     13645
# 116848                15.0                 NaN      8839
# 116849                 NaN                 NaN      6910
# 116850                 NaN                 NaN      7882
# 116851                 4.0                 5.0     13650
# 155570                 NaN                 NaN      7839
# 155571                 8.0                16.0     16622
# 155572                 4.0                12.0     13627
# 194558                 8.0                17.0     19219
# 194559                 8.0                 NaN      2849
# 233726                 NaN                 NaN     11011
# 233727                 NaN                 NaN     10003
# 233728                 NaN                 NaN      8094
# 272808                 NaN                 NaN      9946
# 311709                 NaN                 NaN      7887
# 311710                 4.0                 NaN     10872
# 311711                17.0                 NaN      9938
# 311712                 4.0                 NaN      7943
# 311713                 4.0                 NaN     11039
# 350797                 4.0                 5.0     10900
# 390150                 NaN                 NaN      1715
# 390151                 NaN                 NaN     16446
# 428893                 2.0                 9.0     15416
# 428894                 4.0                12.0     10572
# 467663                 4.0                12.0     11051
# 467664                 NaN                 NaN      7953
# 506601                 4.0                12.0      8190
# 545915                 NaN                 NaN       612

# %%
df2 = df.loc[df['User_ID']==1000001]

# %%
np.mean(df2.Purchase)
# Out:
# 9545.514285714286

# %%
df2.describe()
# Out:
#          User_ID  Occupation  Marital_Status  Product_Category_1  \
# count       35.0        35.0            35.0           35.000000
# mean   1000001.0        10.0             0.0            6.085714
# std          0.0         0.0             0.0            4.616922
# min    1000001.0        10.0             0.0            1.000000
# 25%    1000001.0        10.0             0.0            3.000000
# 50%    1000001.0        10.0             0.0            4.000000
# 75%    1000001.0        10.0             0.0            8.000000
# max    1000001.0        10.0             0.0           20.000000
#
#        Product_Category_2  Product_Category_3      Purchase
# count           21.000000           14.000000     35.000000
# mean             6.285714           10.571429   9545.514286
# std              4.220697            3.897026   4639.871552
# min              2.000000            5.000000    612.000000
# 25%              4.000000            8.250000   7884.500000
# 50%              4.000000           12.000000   9946.000000
# 75%              8.000000           12.000000  12305.500000
# max             17.000000           17.000000  19219.000000

# %%
average_purchase = pd.DataFrame(df.groupby('User_ID')['Purchase'].mean())
average_purchase.rename(columns = {'Purchase':'avg_purchase'}, inplace = True)
print(min(average_purchase.avg_purchase))
print(max(average_purchase.avg_purchase))
average_purchase
# Out:
# 2318.733333333333
# 18577.893617021276
#          avg_purchase
# User_ID
# 1000001   9545.514286
# 1000002  10525.610390
# 1000003  11780.517241
# 1000004  14747.714286
# 1000005   7745.292453
# ...               ...
# 1006036   8007.894942
# 1006037   9176.540984
# 1006038   7502.833333
# 1006039   7977.283784
# 1006040   9184.994444
#
# [5891 rows x 1 columns]

# %%
plt.hist(x = average_purchase.avg_purchase, bins = 30, density = False)
plt.show()

# %%
city_average = pd.DataFrame(df.groupby('City_Category')['Purchase'].mean())
city_average.reset_index(inplace = True)
city_average.rename(columns = {'City_Category':'city', 'Purchase':'avg_purchase'}, inplace = True)
city_average
# Out:
#   city  avg_purchase
# 0    A   8911.939216
# 1    B   9151.300563
# 2    C   9719.920993

# %%
sns.scatterplot(x= city_average['city'], y = city_average.avg_purchase)

# %%
user_city = pd.DataFrame(df.groupby('City_Category')['User_ID'].unique())
user_city.reset_index(inplace = True)
user_city
# Out:
#   City_Category                                            User_ID
# 0             A  [1000001, 1000003, 1000005, 1000006, 1000015, ...
# 1             B  [1000004, 1000007, 1000010, 1000018, 1000021, ...
# 2             C  [1000002, 1000008, 1000009, 1000011, 1000012, ...

# %%
cities = user_city.City_Category
cities
# Out:
# 0    A
# 1    B
# 2    C
# Name: City_Category, dtype: object

# %%
for city in cities:
    length = df.loc[df['City_Category']== city]
    print(len(length.User_ID.unique()))
# Out:
# 1045
# 1707
# 3139

# %%
1045+1707+3139
# Out:
# 5891

# %%
occupation_city = pd.DataFrame(df.groupby('City_Category')['Occupation'].unique())
occupation_city.reset_index(inplace = True)
occupation_city
# Out:
#   City_Category                                         Occupation
# 0             A  [10, 15, 20, 9, 7, 3, 0, 12, 16, 2, 1, 4, 14, ...
# 1             B  [7, 1, 3, 16, 0, 4, 17, 2, 9, 14, 20, 12, 13, ...
# 2             C  [16, 12, 17, 1, 0, 4, 11, 7, 9, 8, 19, 10, 20,...

# %%
jobs = df.Occupation.unique()
jobs
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df.head()
# Out:
#    User_ID  Occupation City_Category  Purchase
# 0  1000001          10             A      8370
# 1  1000001          10             A     15200
# 2  1000001          10             A      1422
# 3  1000001          10             A      1057
# 4  1000002          16             C      7969

# %%
df2 = df
df2.drop(columns = ['Gender','Age','Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1','Product_ID','Purchase',
                    'Product_Category_2', 'Product_Category_3'],inplace = True)
df2
# Out:
#         User_ID  Occupation City_Category
# 0       1000001          10             A
# 1       1000001          10             A
# 2       1000001          10             A
# 3       1000001          10             A
# 4       1000002          16             C
# ...         ...         ...           ...
# 550063  1006033          13             B
# 550064  1006035           1             C
# 550065  1006036          15             B
# 550066  1006038           1             C
# 550067  1006039           0             B
#
# [550068 rows x 3 columns]

# %%
df3 = pd.DataFrame(df2.groupby(['User_ID', 'City_Category'])['Occupation'].unique())

# %%
df3.reset_index(drop = True, inplace = True)
df3.drop(columns = ['index'], inplace = True)
df3
# Out:
#       User_ID City_Category Occupation
# 0     1000001             A       [10]
# 1     1000002             C       [16]
# 2     1000003             A       [15]
# 3     1000004             B        [7]
# 4     1000005             A       [20]
# ...       ...           ...        ...
# 5886  1006036             B       [15]
# 5887  1006037             C        [1]
# 5888  1006038             C        [1]
# 5889  1006039             B        [0]
# 5890  1006040             B        [6]
#
# [5891 rows x 3 columns]

# %%
city_b = df3.loc[df3['City_Category'] == 'B']
city_b.sort_values(by = 'Occupation')
city_b = pd.DataFrame(city_b['Occupation'].value_counts())
city_b.reset_index(inplace = True)
city_b.rename(columns = {'index':'job','Occupation':'number'}, inplace = True)
city_b['job'] = city_b['job'].str.get(0)
city = ['B', 'B','B', 'B','B', 'B','B', 'B','B', 'B','B', 'B','B', 'B','B', 'B','B', 'B','B', 'B','B']
city_b['city'] = city
city_b
# Out:
#     job  number city
# 0     4     236    B
# 1     0     203    B
# 2     7     170    B
# 3     1     140    B
# 4    17     136    B
# 5    12     113    B
# 6    20     106    B
# 7    14      83    B
# 8     2      80    B
# 9     6      74    B
# 10   16      61    B
# 11    3      47    B
# 12   11      44    B
# 13   10      44    B
# 14   15      43    B
# 15    5      40    B
# 16   13      30    B
# 17    9      25    B
# 18   19      18    B
# 19   18      12    B
# 20    8       2    B

# %%
city_c = df3.loc[df3['City_Category'] == 'C']
city_c.sort_values(by = 'Occupation')
city_c = pd.DataFrame(city_c['Occupation'].value_counts())
city_c.reset_index(inplace = True)
city_c.rename(columns = {'index':'job','Occupation':'number'}, inplace = True)
city_c['job'] = city_c['job'].str.get(0)
city = ['C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C']
city_c['city'] = city
city_c
# Out:
#     job  number city
# 0     7     386    C
# 1     0     356    C
# 2     4     332    C
# 3    17     293    C
# 4     1     283    C
# 5    12     186    C
# 6    14     158    C
# 7    16     139    C
# 8     6     130    C
# 9    10     125    C
# 10   20     108    C
# 11    2     108    C
# 12   13      98    C
# 13    3      89    C
# 14   15      72    C
# 15   11      65    C
# 16    5      57    C
# 17    9      56    C
# 18   18      48    C
# 19   19      39    C
# 20    8      11    C

# %%
city_a = df3.loc[df3['City_Category'] == 'A']
city_a.sort_values(by = 'Occupation')
city_a = pd.DataFrame(city_a['Occupation'].value_counts())
city_a.reset_index(inplace = True)
city_a.rename(columns = {'index':'job','Occupation':'number'}, inplace = True)
city_a['job'] = city_a['job'].str.get(0)
city = ['A','A','A','A','A','A','A','A','A','A','A','A','A','A','A','A','A','A','A','A','A']
city_a['city'] = city
city_a
# Out:
#     job  number city
# 0     4     172    A
# 1     0     129    A
# 2     7     113    A
# 3     1      94    A
# 4    12      77    A
# 5     2      68    A
# 6    17      62    A
# 7    20      59    A
# 8    14      53    A
# 9    16      35    A
# 10    3      34    A
# 11   15      25    A
# 12    6      24    A
# 13   10      23    A
# 14   11      19    A
# 15    5      14    A
# 16   19      14    A
# 17   13      12    A
# 18    9       7    A
# 19   18       7    A
# 20    8       4    A

# %%
city_occupation = pd.concat([city_a, city_b, city_c])

# %%
city_occupation[:63]
# Out:
#     job  number city
# 0     4     172    A
# 1     0     129    A
# 2     7     113    A
# 3     1      94    A
# 4    12      77    A
# ..  ...     ...  ...
# 16    5      57    C
# 17    9      56    C
# 18   18      48    C
# 19   19      39    C
# 20    8      11    C
#
# [63 rows x 3 columns]

# %%
sns.barplot(x = city_occupation['job'], y = city_occupation['number'], hue = city_occupation.city)

# %%
city_a
# Out:
#     job  number city
# 0     4     172    A
# 1     0     129    A
# 2     7     113    A
# 3     1      94    A
# 4    12      77    A
# 5     2      68    A
# 6    17      62    A
# 7    20      59    A
# 8    14      53    A
# 9    16      35    A
# 10    3      34    A
# 11   15      25    A
# 12    6      24    A
# 13   10      23    A
# 14   11      19    A
# 15    5      14    A
# 16   19      14    A
# 17   13      12    A
# 18    9       7    A
# 19   18       7    A
# 20    8       4    A

# %%
jobs = list(city_a.job.unique())
jobs
# Out:
# [4, 0, 7, 1, 12, 2, 17, 20, 14, 16, 3, 15, 6, 10, 11, 5, 19, 13, 9, 18, 8]

# %%
values = list(city_a['number'].values)
values
# Out:
# [172,
#  129,
#  113,
#  94,
#  77,
#  68,
#  62,
#  59,
#  53,
#  35,
#  34,
#  25,
#  24,
#  23,
#  19,
#  14,
#  14,
#  12,
#  7,
#  7,
#  4]

# %%
## working on getting percents for each job type in each city for a better graph

# %%
percents=[]
for job in jobs:
    percent = city_a.loc[city_a['job']==job]
    percentage = (percent.number.values)/(sum(city_a.number))
percentage
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-289-2daebae9d895> in <module>
#       2 for job in jobs:
#       3     percent = city_a.loc[city_a['job']==job]
# ----> 4     percentage = (list(percent.number.values))/(sum(city_a.number))
#       5 percentage
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
# Out:
# 172
