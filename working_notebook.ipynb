# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df.Product_Category_1.unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19])

# %%
df.Product_Category_2.unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df.Product_Category_3.unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df.loc[df['User_ID']==1000001]
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 39180   1000001  P00085942      F  0-17          10             A
# 78144   1000001  P00102642      F  0-17          10             A
# 78145   1000001  P00110842      F  0-17          10             A
# 78146   1000001  P00004842      F  0-17          10             A
# 116848  1000001  P00117942      F  0-17          10             A
# 116849  1000001  P00258742      F  0-17          10             A
# 116850  1000001  P00142242      F  0-17          10             A
# 116851  1000001  P00000142      F  0-17          10             A
# 155570  1000001  P00297042      F  0-17          10             A
# 155571  1000001  P00059442      F  0-17          10             A
# 155572  1000001   P0096542      F  0-17          10             A
# 194558  1000001  P00184942      F  0-17          10             A
# 194559  1000001  P00051842      F  0-17          10             A
# 233726  1000001  P00214842      F  0-17          10             A
# 233727  1000001  P00165942      F  0-17          10             A
# 233728  1000001  P00111842      F  0-17          10             A
# 272808  1000001  P00178242      F  0-17          10             A
# 311709  1000001  P00178342      F  0-17          10             A
# 311710  1000001  P00183942      F  0-17          10             A
# 311711  1000001  P00051442      F  0-17          10             A
# 311712  1000001  P00248442      F  0-17          10             A
# 311713  1000001  P00210342      F  0-17          10             A
# 350797  1000001  P00289942      F  0-17          10             A
# 390150  1000001   P0097142      F  0-17          10             A
# 390151  1000001  P00255842      F  0-17          10             A
# 428893  1000001  P00025442      F  0-17          10             A
# 428894  1000001  P00074142      F  0-17          10             A
# 467663  1000001  P00058142      F  0-17          10             A
# 467664  1000001  P00220642      F  0-17          10             A
# 506601  1000001  P00064042      F  0-17          10             A
# 545915  1000001  P00375436      F  0-17          10             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 39180                           2               0                   2
# 78144                           2               0                   4
# 78145                           2               0                   1
# 78146                           2               0                   3
# 116848                          2               0                   5
# 116849                          2               0                   5
# 116850                          2               0                   8
# 116851                          2               0                   3
# 155570                          2               0                   8
# 155571                          2               0                   6
# 155572                          2               0                   3
# 194558                          2               0                   1
# 194559                          2               0                   4
# 233726                          2               0                  14
# 233727                          2               0                   8
# 233728                          2               0                   8
# 272808                          2               0                   8
# 311709                          2               0                   8
# 311710                          2               0                   3
# 311711                          2               0                   8
# 311712                          2               0                   3
# 311713                          2               0                   3
# 350797                          2               0                   3
# 390150                          2               0                  12
# 390151                          2               0                  16
# 428893                          2               0                   1
# 428894                          2               0                   3
# 467663                          2               0                   3
# 467664                          2               0                   8
# 506601                          2               0                   3
# 545915                          2               0                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 39180                  4.0                 8.0     12842
# 78144                  8.0                 9.0      2763
# 78145                  2.0                 5.0     11769
# 78146                  4.0                12.0     13645
# 116848                15.0                 NaN      8839
# 116849                 NaN                 NaN      6910
# 116850                 NaN                 NaN      7882
# 116851                 4.0                 5.0     13650
# 155570                 NaN                 NaN      7839
# 155571                 8.0                16.0     16622
# 155572                 4.0                12.0     13627
# 194558                 8.0                17.0     19219
# 194559                 8.0                 NaN      2849
# 233726                 NaN                 NaN     11011
# 233727                 NaN                 NaN     10003
# 233728                 NaN                 NaN      8094
# 272808                 NaN                 NaN      9946
# 311709                 NaN                 NaN      7887
# 311710                 4.0                 NaN     10872
# 311711                17.0                 NaN      9938
# 311712                 4.0                 NaN      7943
# 311713                 4.0                 NaN     11039
# 350797                 4.0                 5.0     10900
# 390150                 NaN                 NaN      1715
# 390151                 NaN                 NaN     16446
# 428893                 2.0                 9.0     15416
# 428894                 4.0                12.0     10572
# 467663                 4.0                12.0     11051
# 467664                 NaN                 NaN      7953
# 506601                 4.0                12.0      8190
# 545915                 NaN                 NaN       612

# %%
df2 = df.loc[df['User_ID']==1000004]
df2.describe()
# Out:
#          User_ID  Occupation  Marital_Status  Product_Category_1  \
# count       14.0        14.0            14.0           14.000000
# mean   1000004.0         7.0             1.0            2.357143
# std          0.0         0.0             0.0            5.077964
# min    1000004.0         7.0             1.0            1.000000
# 25%    1000004.0         7.0             1.0            1.000000
# 50%    1000004.0         7.0             1.0            1.000000
# 75%    1000004.0         7.0             1.0            1.000000
# max    1000004.0         7.0             1.0           20.000000
#
#        Product_Category_2  Product_Category_3      Purchase
# count           12.000000            9.000000     14.000000
# mean             8.500000           14.111111  14747.714286
# std              5.760366            2.571208   5801.640132
# min              2.000000            9.000000    481.000000
# 25%              2.000000           14.000000  15488.500000
# 50%              8.000000           15.000000  15852.500000
# 75%             15.000000           16.000000  19087.000000
# max             16.000000           17.000000  19693.000000

# %%
users = list(df.User_ID.unique())
users
# Out:
# [1000001,
#  1000002,
#  1000003,
#  1000004,
#  1000005,
#  1000006,
#  1000007,
#  1000008,
#  1000009,
#  1000010,
#  1000011,
#  1000012,
#  1000013,
#  1000014,
#  1000015,
#  1000016,
#  1000017,
#  1000018,
#  1000019,
#  1000021,
#  1000022,
#  1000023,
#  1000024,
#  1000025,
#  1000026,
#  1000027,
#  1000028,
#  1000029,
#  1000030,
#  1000031,
#  1000032,
#  1000033,
#  1000034,
#  1000035,
#  1000036,
#  1000037,
#  1000039,
#  1000041,
#  1000042,
#  1000043,
#  1000044,
#  1000045,
#  1000046,
#  1000047,
#  1000048,
#  1000049,
#  1000050,
#  1000051,
#  1000052,
#  1000053,
#  1000054,
#  1000056,
#  1000057,
#  1000058,
#  1000059,
#  1000060,
#  1000061,
#  1000062,
#  1000063,
#  1000064,
#  1000065,
#  1000066,
#  1000067,
#  1000068,
#  1000069,
#  1000070,
#  1000071,
#  1000072,
#  1000073,
#  1000074,
#  1000075,
#  1000076,
#  1000077,
#  1000078,
#  1000079,
#  1000080,
#  1000081,
#  1000082,
#  1000083,
#  1000084,
#  1000085,
#  1000086,
#  1000087,
#  1000088,
#  1000089,
#  1000090,
#  1000091,
#  1000092,
#  1000093,
#  1000094,
#  1000095,
#  1000096,
#  1000097,
#  1000099,
#  1000100,
#  1000101,
#  1000102,
#  1000103,
#  1000105,
#  1000106,
#  1000107,
#  1000108,
#  1000109,
#  1000110,
#  1000111,
#  1000112,
#  1000113,
#  1000114,
#  1000116,
#  1000117,
#  1000118,
#  1000119,
#  1000120,
#  1000121,
#  1000122,
#  1000123,
#  1000124,
#  1000125,
#  1000126,
#  1000127,
#  1000128,
#  1000129,
#  1000130,
#  1000131,
#  1000132,
#  1000133,
#  1000134,
#  1000135,
#  1000136,
#  1000137,
#  1000138,
#  1000139,
#  1000140,
#  1000142,
#  1000143,
#  1000145,
#  1000146,
#  1000147,
#  1000148,
#  1000149,
#  1000150,
#  1000151,
#  1000152,
#  1000153,
#  1000154,
#  1000155,
#  1000156,
#  1000157,
#  1000158,
#  1000159,
#  1000160,
#  1000161,
#  1000162,
#  1000163,
#  1000165,
#  1000166,
#  1000169,
#  1000170,
#  1000171,
#  1000172,
#  1000173,
#  1000174,
#  1000175,
#  1000176,
#  1000177,
#  1000178,
#  1000179,
#  1000180,
#  1000181,
#  1000182,
#  1000183,
#  1000184,
#  1000185,
#  1000186,
#  1000187,
#  1000188,
#  1000190,
#  1000191,
#  1000192,
#  1000193,
#  1000194,
#  1000195,
#  1000196,
#  1000197,
#  1000198,
#  1000199,
#  1000200,
#  1000201,
#  1000202,
#  1000203,
#  1000204,
#  1000205,
#  1000206,
#  1000208,
#  1000209,
#  1000210,
#  1000211,
#  1000212,
#  1000214,
#  1000215,
#  1000216,
#  1000217,
#  1000218,
#  1000219,
#  1000220,
#  1000221,
#  1000222,
#  1000223,
#  1000225,
#  1000227,
#  1000228,
#  1000229,
#  1000230,
#  1000231,
#  1000232,
#  1000233,
#  1000234,
#  1000235,
#  1000236,
#  1000237,
#  1000238,
#  1000239,
#  1000240,
#  1000242,
#  1000243,
#  1000244,
#  1000245,
#  1000246,
#  1000249,
#  1000250,
#  1000251,
#  1000252,
#  1000253,
#  1000254,
#  1000255,
#  1000256,
#  1000257,
#  1000258,
#  1000259,
#  1000260,
#  1000261,
#  1000262,
#  1000263,
#  1000264,
#  1000265,
#  1000266,
#  1000267,
#  1000268,
#  1000269,
#  1000270,
#  1000271,
#  1000272,
#  1000273,
#  1000274,
#  1000275,
#  1000276,
#  1000278,
#  1000279,
#  1000280,
#  1000281,
#  1000282,
#  1000284,
#  1000285,
#  1000287,
#  1000289,
#  1000291,
#  1000292,
#  1000293,
#  1000295,
#  1000296,
#  1000297,
#  1000298,
#  1000299,
#  1000300,
#  1000301,
#  1000302,
#  1000303,
#  1000304,
#  1000305,
#  1000306,
#  1000307,
#  1000308,
#  1000309,
#  1000310,
#  1000311,
#  1000312,
#  1000313,
#  1000314,
#  1000315,
#  1000316,
#  1000318,
#  1000319,
#  1000320,
#  1000321,
#  1000322,
#  1000323,
#  1000324,
#  1000325,
#  1000326,
#  1000327,
#  1000328,
#  1000329,
#  1000330,
#  1000331,
#  1000332,
#  1000333,
#  1000334,
#  1000335,
#  1000336,
#  1000337,
#  1000338,
#  1000339,
#  1000340,
#  1000342,
#  1000343,
#  1000344,
#  1000345,
#  1000346,
#  1000347,
#  1000348,
#  1000349,
#  1000350,
#  1000351,
#  1000352,
#  1000353,
#  1000354,
#  1000355,
#  1000356,
#  1000357,
#  1000359,
#  1000360,
#  1000362,
#  1000363,
#  1000365,
#  1000366,
#  1000368,
#  1000369,
#  1000370,
#  1000371,
#  1000372,
#  1000374,
#  1000375,
#  1000376,
#  1000377,
#  1000379,
#  1000380,
#  1000381,
#  1000382,
#  1000383,
#  1000384,
#  1000385,
#  1000386,
#  1000387,
#  1000388,
#  1000389,
#  1000390,
#  1000391,
#  1000392,
#  1000393,
#  1000394,
#  1000396,
#  1000397,
#  1000398,
#  1000399,
#  1000400,
#  1000401,
#  1000402,
#  1000403,
#  1000405,
#  1000406,
#  1000408,
#  1000409,
#  1000410,
#  1000411,
#  1000412,
#  1000413,
#  1000414,
#  1000415,
#  1000416,
#  1000417,
#  1000418,
#  1000419,
#  1000420,
#  1000421,
#  1000422,
#  1000423,
#  1000424,
#  1000425,
#  1000426,
#  1000429,
#  1000430,
#  1000431,
#  1000433,
#  1000434,
#  1000435,
#  1000436,
#  1000437,
#  1000438,
#  1000439,
#  1000442,
#  1000443,
#  1000444,
#  1000445,
#  1000446,
#  1000447,
#  1000448,
#  1000449,
#  1000450,
#  1000451,
#  1000452,
#  1000453,
#  1000454,
#  1000456,
#  1000457,
#  1000458,
#  1000459,
#  1000460,
#  1000461,
#  1000462,
#  1000463,
#  1000464,
#  1000465,
#  1000466,
#  1000467,
#  1000468,
#  1000469,
#  1000470,
#  1000471,
#  1000473,
#  1000474,
#  1000476,
#  1000477,
#  1000478,
#  1000479,
#  1000480,
#  1000481,
#  1000482,
#  1000483,
#  1000484,
#  1000486,
#  1000487,
#  1000490,
#  1000492,
#  1000493,
#  1000496,
#  1000498,
#  1000499,
#  1000500,
#  1000501,
#  1000502,
#  1000503,
#  1000504,
#  1000505,
#  1000506,
#  1000507,
#  1000508,
#  1000509,
#  1000510,
#  1000511,
#  1000513,
#  1000514,
#  1000515,
#  1000516,
#  1000517,
#  1000518,
#  1000519,
#  1000520,
#  1000522,
#  1000523,
#  1000524,
#  1000525,
#  1000526,
#  1000529,
#  1000530,
#  1000531,
#  1000532,
#  1000533,
#  1000534,
#  1000535,
#  1000536,
#  1000539,
#  1000540,
#  1000541,
#  1000543,
#  1000544,
#  1000545,
#  1000546,
#  1000547,
#  1000548,
#  1000549,
#  1000550,
#  1000551,
#  1000552,
#  1000553,
#  1000554,
#  1000555,
#  1000556,
#  1000557,
#  1000560,
#  1000563,
#  1000564,
#  1000565,
#  1000566,
#  1000567,
#  1000568,
#  1000569,
#  1000570,
#  1000571,
#  1000573,
#  1000574,
#  1000575,
#  1000576,
#  1000577,
#  1000579,
#  1000580,
#  1000581,
#  1000582,
#  1000583,
#  1000584,
#  1000585,
#  1000586,
#  1000587,
#  1000588,
#  1000589,
#  1000590,
#  1000591,
#  1000592,
#  1000593,
#  1000594,
#  1000595,
#  1000596,
#  1000597,
#  1000598,
#  1000599,
#  1000600,
#  1000601,
#  1000602,
#  1000603,
#  1000604,
#  1000605,
#  1000606,
#  1000608,
#  1000609,
#  1000610,
#  1000611,
#  1000612,
#  1000613,
#  1000615,
#  1000616,
#  1000617,
#  1000618,
#  1000619,
#  1000620,
#  1000622,
#  1000623,
#  1000624,
#  1000625,
#  1000626,
#  1000627,
#  1000628,
#  1000629,
#  1000630,
#  1000631,
#  1000632,
#  1000633,
#  1000634,
#  1000635,
#  1000636,
#  1000637,
#  1000638,
#  1000639,
#  1000641,
#  1000643,
#  1000644,
#  1000645,
#  1000646,
#  1000647,
#  1000648,
#  1000649,
#  1000650,
#  1000651,
#  1000652,
#  1000654,
#  1000655,
#  1000656,
#  1000657,
#  1000658,
#  1000659,
#  1000661,
#  1000662,
#  1000663,
#  1000664,
#  1000666,
#  1000667,
#  1000668,
#  1000669,
#  1000670,
#  1000671,
#  1000673,
#  1000674,
#  1000675,
#  1000676,
#  1000677,
#  1000678,
#  1000679,
#  1000680,
#  1000681,
#  1000682,
#  1000683,
#  1000685,
#  1000686,
#  1000687,
#  1000688,
#  1000689,
#  1000690,
#  1000691,
#  1000692,
#  1000694,
#  1000695,
#  1000698,
#  1000700,
#  1000701,
#  1000702,
#  1000704,
#  1000705,
#  1000706,
#  1000707,
#  1000708,
#  1000709,
#  1000710,
#  1000711,
#  1000712,
#  1000713,
#  1000714,
#  1000715,
#  1000717,
#  1000718,
#  1000719,
#  1000720,
#  1000721,
#  1000722,
#  1000723,
#  1000724,
#  1000725,
#  1000726,
#  1000727,
#  1000728,
#  1000729,
#  1000730,
#  1000731,
#  1000732,
#  1000733,
#  1000734,
#  1000735,
#  1000736,
#  1000737,
#  1000738,
#  1000739,
#  1000740,
#  1000741,
#  1000742,
#  1000743,
#  1000744,
#  1000746,
#  1000748,
#  1000749,
#  1000750,
#  1000751,
#  1000752,
#  1000753,
#  1000754,
#  1000755,
#  1000756,
#  1000757,
#  1000758,
#  1000759,
#  1000760,
#  1000761,
#  1000762,
#  1000764,
#  1000765,
#  1000766,
#  1000767,
#  1000769,
#  1000770,
#  1000771,
#  1000772,
#  1000773,
#  1000774,
#  1000775,
#  1000776,
#  1000777,
#  1000778,
#  1000779,
#  1000780,
#  1000783,
#  1000785,
#  1000786,
#  1000787,
#  1000788,
#  1000789,
#  1000791,
#  1000792,
#  1000793,
#  1000794,
#  1000795,
#  1000796,
#  1000797,
#  1000798,
#  1000799,
#  1000801,
#  1000802,
#  1000803,
#  1000804,
#  1000805,
#  1000806,
#  1000807,
#  1000808,
#  1000809,
#  1000810,
#  1000811,
#  1000812,
#  1000813,
#  1000814,
#  1000816,
#  1000817,
#  1000818,
#  1000819,
#  1000820,
#  1000821,
#  1000822,
#  1000823,
#  1000824,
#  1000825,
#  1000826,
#  1000827,
#  1000828,
#  1000829,
#  1000830,
#  1000832,
#  1000833,
#  1000834,
#  1000835,
#  1000836,
#  1000837,
#  1000838,
#  1000839,
#  1000840,
#  1000842,
#  1000843,
#  1000844,
#  1000845,
#  1000846,
#  1000847,
#  1000848,
#  1000849,
#  1000850,
#  1000851,
#  1000852,
#  1000853,
#  1000854,
#  1000855,
#  1000856,
#  1000857,
#  1000858,
#  1000859,
#  1000860,
#  1000861,
#  1000862,
#  1000863,
#  1000864,
#  1000867,
#  1000868,
#  1000869,
#  1000870,
#  1000871,
#  1000872,
#  1000873,
#  1000875,
#  1000877,
#  1000878,
#  1000880,
#  1000881,
#  1000882,
#  1000883,
#  1000884,
#  1000885,
#  1000886,
#  1000887,
#  1000888,
#  1000889,
#  1000890,
#  1000891,
#  1000892,
#  1000894,
#  1000895,
#  1000896,
#  1000897,
#  1000898,
#  1000899,
#  1000900,
#  1000901,
#  1000903,
#  1000904,
#  1000905,
#  1000906,
#  1000908,
#  1000909,
#  1000910,
#  1000911,
#  1000912,
#  1000913,
#  1000914,
#  1000915,
#  1000917,
#  1000918,
#  1000919,
#  1000920,
#  1000921,
#  1000922,
#  1000923,
#  1000924,
#  1000925,
#  1000926,
#  1000927,
#  1000928,
#  1000929,
#  1000930,
#  1000931,
#  1000932,
#  1000933,
#  1000934,
#  1000936,
#  1000937,
#  1000939,
#  1000940,
#  1000943,
#  1000944,
#  1000945,
#  1000949,
#  1000950,
#  1000951,
#  1000952,
#  1000953,
#  1000954,
#  1000955,
#  1000956,
#  1000957,
#  1000958,
#  1000959,
#  1000960,
#  1000961,
#  1000963,
#  1000964,
#  1000966,
#  1000967,
#  1000968,
#  1000969,
#  1000970,
#  1000971,
#  1000972,
#  1000973,
#  1000974,
#  1000975,
#  1000976,
#  1000977,
#  1000978,
#  1000979,
#  1000980,
#  1000981,
#  1000982,
#  1000983,
#  1000984,
#  1000985,
#  1000986,
#  1000987,
#  1000988,
#  1000989,
#  1000990,
#  1000991,
#  1000992,
#  1000993,
#  1000995,
#  1000996,
#  1000997,
#  1000998,
#  1000999,
#  1001000,
#  1001002,
#  1001003,
#  1001004,
#  1001005,
#  1001006,
#  1001008,
#  1001009,
#  1001010,
#  1001011,
#  1001012,
#  1001013,
#  1001015,
#  1001016,
#  1001017,
#  1001018,
#  1001019,
#  1001021,
#  1001022,
#  1001023,
#  1001024,
#  1001025,
#  1001026,
#  1001027,
#  1001028,
#  1001029,
#  1001030,
#  1001031,
#  1001032,
#  1001033,
#  1001035,
#  1001036,
#  1001037,
#  1001038,
#  1001039,
#  1001040,
#  1001041,
#  1001042,
#  1001043,
#  1001044,
#  1001045,
#  1001047,
#  1001048,
#  1001049,
#  1001050,
#  1001051,
#  1001052,
#  1001053,
#  1001054,
#  1001055,
#  1001056,
#  1001057,
#  1001058,
#  1001059,
#  1001060,
#  1001061,
#  1001062,
#  1001063,
#  1001064,
#  1001065,
#  1001066,
#  1001067,
#  1001068,
#  1001069,
#  1001071,
#  1001072,
#  1001073,
#  1001074,
#  1001075,
#  1001076,
#  1001077,
#  1001078,
#  1001079,
#  1001081,
#  1001083,
#  1001084,
#  1001086,
#  1001087,
#  1001088,
#  1001089,
#  1001090,
#  1001091,
#  1001092,
#  1001093,
#  1001094,
#  1001096,
#  1001097,
#  1001098,
#  1001099,
#  1001100,
#  1001101,
#  1001102,
#  1001103,
#  1001104,
#  1001106,
#  1001107,
#  1001108,
#  1001109,
#  1001110,
#  1001111,
#  1001112,
#  1001113,
#  1001114,
#  1001116,
#  1001117,
#  1001118,
#  1001119,
#  1001120,
#  1001121,
#  1001122,
#  1001124,
#  1001125,
#  1001126,
#  ...]

# %%
df2 = df.loc[df['User_ID']==1000001]

# %%
np.mean(df2.Purchase)
# Out:
# 9545.514285714286

# %%
df2.describe()
# Out:
#          User_ID  Occupation  Marital_Status  Product_Category_1  \
# count       77.0        77.0            77.0           77.000000
# mean   1000002.0        16.0             0.0            4.597403
# std          0.0         0.0             0.0            3.532778
# min    1000002.0        16.0             0.0            1.000000
# 25%    1000002.0        16.0             0.0            1.000000
# 50%    1000002.0        16.0             0.0            5.000000
# 75%    1000002.0        16.0             0.0            8.000000
# max    1000002.0        16.0             0.0           20.000000
#
#        Product_Category_2  Product_Category_3      Purchase
# count           54.000000           26.000000     77.000000
# mean             9.981481           13.807692  10525.610390
# std              4.935397            3.475851   4301.736734
# min              2.000000            6.000000    119.000000
# 25%              8.000000           13.000000   7818.000000
# 50%              8.000000           14.500000   9899.000000
# 75%             15.000000           16.750000  11973.000000
# max             17.000000           18.000000  20657.000000

# %%
average_purchase = pd.DataFrame(df.groupby('User_ID')['Purchase'].mean())
average_purchase.rename(columns = {'Purchase':'avg_purchase'}, inplace = True)
print(min(average_purchase.avg_purchase))
print(max(average_purchase.avg_purchase))
average_purchase
# Out:
# 2318.733333333333
# 18577.893617021276
#          avg_purchase
# User_ID
# 1000001   9545.514286
# 1000002  10525.610390
# 1000003  11780.517241
# 1000004  14747.714286
# 1000005   7745.292453
# ...               ...
# 1006036   8007.894942
# 1006037   9176.540984
# 1006038   7502.833333
# 1006039   7977.283784
# 1006040   9184.994444
#
# [5891 rows x 1 columns]

# %%
plt.hist(x = average_purchase.avg_purchase, bins = 30, density = False)
plt.show()

# %%
city_average = pd.DataFrame(df.groupby('City_Category')['Purchase'].mean())
city_average.reset_index(inplace = True)
city_average.rename(columns = {'City_Category':'city', 'Purchase':'avg_purchase'}, inplace = True)
city_average
# Out:
#   city  avg_purchase
# 0    A   8911.939216
# 1    B   9151.300563
# 2    C   9719.920993

# %%
sns.scatterplot(x= city_average['city'], y = city_average.avg_purchase)

# %%
user_city = pd.DataFrame(df.groupby('City_Category')['User_ID'].unique())
user_city.reset_index(inplace = True)
user_city
# Out:
#   City_Category                                            User_ID
# 0             A  [1000001, 1000003, 1000005, 1000006, 1000015, ...
# 1             B  [1000004, 1000007, 1000010, 1000018, 1000021, ...
# 2             C  [1000002, 1000008, 1000009, 1000011, 1000012, ...

# %%
user_city.City_Category['A'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-229-a68173c88689> in <module>
# ----> 1 user_city.City_Category['A'].value_counts()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'A'
